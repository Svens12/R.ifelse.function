# %%
x<-5

# %%
ifelse(x>=0, 'Positive Number', 'Negative Number')
# Out:
# [1] "Positive Number"

# %%
x<- -4
ifelse(x>=0, 'Positive Number', 'Negative Number')
# Out:
# [1] "Negative Number"

# %%
x<- -4
ifelse(x%%2==0, 'Even Number', 'Odd Number')
# Out:
# [1] "Even Number"

# %%
x<- 7
ifelse(x%%2==0, 'Even Number', 'Odd Number')
# Out:
# [1] "Odd Number"
